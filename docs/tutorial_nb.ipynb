# %% [markdown]
# # CMC Dict

# %%
import cmcdict

# %% [markdown]
# ## Create a dataframe of all current metvars

# %%
import pandas as pd
with open('nomvar_list.txt') as f:
    vars = f.readlines()

vars = [var.replace('\n', '').strip() for var in vars]

print(f'There are {len(vars)} vars in the dictionnary')

print(f'Looking up all variables for their current version')

mylist = []
for var in vars:
    mylist.append(cmcdict.get_metvar_metadata(var))

mylist = [i for i in mylist if i is not None]


df = pd.DataFrame(mylist)
df
# Out:
# There are 1308 vars in the dictionnary
# Looking up all variables for their current version
#      nomvar  origin        date     type  \
# 0        !!     RPN  2010-04-07     real
# 1        ##    CMOE  2014-05-22  integer
# 2        1A                         real
# 3        1P                         real
# 4        1T                         real
# ...     ...     ...         ...      ...
# 1221     ZV                         real
# 1222    ZVC  SPOOKI  2013-05-24     real
# 1223    ZVE  SPOOKI  2013-05-24     real
# 1224     ZZ                         real
# 1225     ^^     RPN                 real
#
#                             description_short_en  \
# 0                 Vertical coordinate descriptor
# 1       Vertices index of triangular meshe (TIN)
# 2                   Visible Albedo (Entry value)
# 3                            Tropopause pressure
# 4                  Temperature at the tropopause
# ...                                          ...
# 1221  Roughness length due to vegetation (ECMWF)
# 1222                         LFC height using VT
# 1223    Height of the equilibrium level using VT
# 1224              Vertical motion (Z Coordinate)
# 1225  Position along the y-axis in a Y or Z grid
#
#                                    description_short_fr  \
# 0                Descripteur de la coordonnée verticale
# 1          Index des vertices d'une triangulation (TIN)
# 2                            Albédo Visible (en Entrée)
# 3                              Pression à la tropopause
# 4                          Température de la tropopause
# ...                                                 ...
# 1221          Rugosité associée à la végétation (ECMWF)
# 1222                        Hauteur du NCL utilisant VT
# 1223         Hauteur du niveau d'équilibre utilisant VT
# 1224                 Mouvement vertical en coordonnée Z
# 1225  Position selon l'axe des y dans une grille Y ou Z
#
#                                     description_long_en  \
# 0     Contains all the informations needed to descri...
# 1     Index of the vertices position encoded in the ...
# 2
# 3
# 4
# ...                                                 ...
# 1221
# 1222  Height of  the level of free convection using ...
# 1223  Height of the equilibrium level using the virt...
# 1224
# 1225            May be represented in degrees or metres
#
#                                     description_long_fr     units  min    max  \
# 0     Contient toute l'information nécéssaire pour d...       nil
# 1     Index des position de vertices dans les champs...       nil
# 2                                                        fraction  0.0    1.0
# 3                                                             hPa
# 4                                                              °C
# ...                                                 ...       ...  ...    ...
# 1221                                                            m
# 1222  Hauteur du niveau de convection libre utilisan...     m agl    0  20000
# 1223  Hauteur du niveau d'équilibre utilisant la cor...     m agl    0  20000
# 1224                                                          m/s
# 1225           Peut être representé en degrés ou mètres     deg|m
#
#      codes precision magnitude
# 0     None      1e-8
# 1     None
# 2     None
# 3     None
# 4     None
# ...    ...       ...       ...
# 1221  None
# 1222  None
# 1223  None
# 1224  None
# 1225  None      1e-8
#
# [1226 rows x 14 columns]

# %% [markdown]
# ## Create a dataframe of all typvars

# %%
import pandas as pd
with open('typvar_list.txt') as f:
    vars = f.readlines()

vars = [var.replace('\n', '') for var in vars]

print(f'There are {len(vars)} typvars in the dictionnary')

print(f'Looking up all typvars for their current version')

mylist = []
for var in vars:
    mylist.append(cmcdict.get_typvar_metadata(var))

mylist = [i for i in mylist if i is not None]


df = pd.DataFrame(mylist)
df
# Out:
# There are 24 typvars in the dictionnary
# Looking up all typvars for their current version
#    typvar        date                               description_short_en  \
# 0       A                                                       Analysis
# 1       C                                                    Climatology
# 2       D                                               Raw station data
# 3       E                                                  Monthly error
# 4       F                                                       Filtered
# 5       I                                                   Interpolated
# 6       K                                              Various constants
# 7       M                                         Multiple modifications
# 8       M                           Verification Matrix Contigency Table
# 9       O                                                    Observation
# 10      P                                                       Forecast
# 11      Q                                                 Diagnostic QPF
# 12      R                                             Analysis increment
# 13      S                                                 Various scores
# 14      T                                                    Time series
# 15      U                                                 Unit converted
# 16      X                                                        Various
# 17      Z                                                         Zapped
# 18      !                              Variable modified by its 'ETIKET'
# 19      B                                                        Bounded
# 20      @                                                           Mask
# 21     !@  2022-12-20  Mask of field where the variable is modified b...
# 22     N@  2022-12-20  Number of members used to compute the associat...
# 23      H  2022-12-20                                       Missing data
#
#                                  description_short_fr
# 0                                             Analyse
# 1                                        Climatologie
# 2                         Données brutes aux stations
# 3                                    Erreur mensuelle
# 4                                              Filtré
# 5                                           Interpolé
# 6                                  Constantes variées
# 7                             Modifications multiples
# 8         Matrice de vérification (table contingente)
# 9                                         Observation
# 10                                          Prévision
# 11                                   QPF diagnostique
# 12                                Incrément d'analyse
# 13                                      Scores divers
# 14                                   Série temporelle
# 15                                  Unités converties
# 16                                             Divers
# 17                                              Zappé
# 18                 Variable modifiée par son 'ETIKET'
# 19                                              Borné
# 20                                             Masque
# 21  Masque du champ dont la variable est modifiée ...
# 22  Nombre de membres utilisés pour le calcul du c...
# 23                                 Données manquantes

# %% [markdown]
# ## Get a single metvar

# %%
cmcdict.get_metvar_metadata('TT')
# Out:
# {'nomvar': 'TT',
#  'origin': '',
#  'date': '',
#  'type': 'real',
#  'description_short_en': 'Air temperature',
#  'description_short_fr': "Température de l'air",
#  'description_long_en': '',
#  'description_long_fr': '',
#  'units': '°C',
#  'min': '',
#  'max': '',
#  'codes': None,
#  'precision': '',
#  'magnitude': ''}

# %% [markdown]
# ## Get a single typvar

# %%
cmcdict.get_typvar_metadata('K')
# Out:
# {'typvar': 'K',
#  'date': '',
#  'description_short_en': 'Various constants',
#  'description_short_fr': 'Constantes variées'}
